# %%
import torch
import torch.nn as nn

import matplotlib.pyplot as plt

from dataset import generate_input

# %% [markdown]
# #### Load one image from dataset

# %%
input_image = torch.randn(1, 3, 128, 128) # 1 image, 3 channels, 128x128 pixels
# plot 
plt.imshow(input_image[0][0].numpy(), cmap='gray')
